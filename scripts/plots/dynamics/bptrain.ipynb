# %%
import brainpy as bp
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import jax
import jax.numpy as jnp
import sys
import os

src_dir = os.path.abspath(os.path.join('../../../'))
sys.path.insert(0, src_dir)
import src
# plt.style.use('../../../foresight.mplstyle')

# %%
N_e = 10000
J_e = 0.0008 # Microsiemens
delta = 4.0 # 2.9
nu = 10 # Preserve; the minimum required for spontaneous spiking
n_ext = 100

alpha = 0.03 # This alpha actually controls the frequency of ping; smaller alpha, higher frequency...
omega_ee = 0.2*alpha
omega_ie = 0.6*alpha
omega_ei = 0.3*alpha
omega_ii = 0.8*alpha
